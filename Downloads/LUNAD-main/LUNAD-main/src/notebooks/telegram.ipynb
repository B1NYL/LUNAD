# %%
await listen(SOLAD_TOKEN)
# Out:
# 안녕하십니까. 저는 조수아 입니다.
# 정말로 그렇습니다. 이것은 모두
# 이것이 모두 다 배후 세력의
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File ~/areas/LUNAD/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/areas/LUNAD/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/areas/LUNAD/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
# ...
