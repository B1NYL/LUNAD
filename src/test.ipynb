# %%
dotenv.load_dotenv()
LUNAD_TOKEN = os.environ["LUNAD_TOKEN"]
SOLAD_TOKEN = os.environ["SOLAD_TOKEN"]

# %%
# Out:
# Running PyMODI+ (v0.4.2)
# Initiating serial connection...
# Serial is open at "/dev/ttyACM0"
# Start initializing connected MODI+ modules
# Network(0xA5C) has been connected!
# Battery(0x1C2) has been connected!
# Button(0xF24) has been connected!
# MODI+ modules are initialized!
# ...
# Motor(0x76F) has been connected!

# %%
motor.set_angle(30)

# %%
motor = gigi.motors[0]
# motor.target_speed(10.0)
time.sleep(1)
motor.set_angle(180)
time.sleep(1)
motor.set_angle(50)

# %%
await arm_ctrl()
# Out:
# Battery(0x1C2) has been reconnected!
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 await arm_ctrl()
#
# Cell In[6], line 14, in arm_ctrl()
#      10             motor.set_angle(now_ang)
#      11         else:
#      12             now_ang = DN_ANG
#      13             motor.set_angle(now_ang)
# ---> 14         await asyncio.sleep(0.01)
#
# File /nix/store/71d4s2c3dfqk4afkjp8w8g4l3f1glcsy-python3-3.12.13/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:
