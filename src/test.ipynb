# %%
import sob
import os
import dotenv
dotenv.load_dotenv()
LUNAD_TOKEN = os.environ["LUNAD_TOKEN"]
SOLAD_TOKEN = os.environ["SOLAD_TOKEN"]

# %%
await sob.send(LUNAD_TOKEN, sob.s2t(sob.rec(3)))

# %%
await sob.listen(SOLAD_TOKEN)
# Out:
# 크로스플레이바 이것이 모든 배우 세력의 음모입니다 여러분
