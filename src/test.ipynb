# %%
import ctrl
await ctrl.arm_ctrl()
await ctrl.check_fall()
# Out:
# Running PyMODI+ (v0.4.2)
# Initiating serial connection...
# Serial is open at "/dev/ttyACM0"
# Start initializing connected MODI+ modules
# Network(0xA5C) has been connected!
# Motor(0x76F) has been connected!
# Imu(0xD) has been connected!
# Button(0xF24) has been connected!
# Battery(0x1C2) has been connected!
# MODI+ modules are initialized!
# [<modi_plus.module.setup_module.network.Network object at 0x72a6b5df4200>, <modi_plus.module.output_module.motor.Motor object at 0x72a6b414a3c0>, <modi_plus.module.input_module.imu.Imu object at 0x72a6b4148410>, <modi_plus.module.input_module.button.Button object at 0x72a6b5d64380>, <modi_plus.module.setup_module.battery.Battery object at 0x72a6c00a1430>]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import ctrl
# ----> 2 await ctrl.arm_ctrl()
#
# ...
