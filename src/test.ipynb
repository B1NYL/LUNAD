# %%
dotenv.load_dotenv()
LUNAD_TOKEN = os.environ["LUNAD_TOKEN"]
SOLAD_TOKEN = os.environ["SOLAD_TOKEN"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dotenv.load_dotenv()
#       2 LUNAD_TOKEN = os.environ["LUNAD_TOKEN"]
#       3 SOLAD_TOKEN = os.environ["SOLAD_TOKEN"]
#
# NameError: name 'dotenv' is not defined

# %%
motor.set_angle(30)

# %%
motor = gigi.motors[0]
time.sleep(1)
motor.set_angle(180)
time.sleep(1)
motor.set_angle(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 motor = gigi.motors[0]
#       2 time.sleep(1)
#       3 motor.set_angle(180)
#       4 time.sleep(1)
#
# NameError: name 'gigi' is not defined

# %%
import ctrl
await ctrl.arm_ctrl()
# Out:
# Running PyMODI+ (v0.4.2)
# Initiating serial connection...
# Serial is open at "/dev/ttyACM0"
# Start initializing connected MODI+ modules
# Network(0xA5C) has been connected!
# Battery(0x1C2) has been connected!
# MODI+ modules are initialized!
# Motor(0x76F) has been connected!
# Button(0xF24) has been connected!
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import ctrl
# ----> 2 await ctrl.arm_ctrl()
#
# File ~/areas/LUNAD/src/ctrl.py:20, in arm_ctrl(dn_ang, up_ang)
#      18     now_ang = dn_ang
#      19 motor.set_angle(now_ang)
# ---> 20 await asyncio.sleep(0.01)
#
# File /nix/store/71d4s2c3dfqk4afkjp8w8g4l3f1glcsy-python3-3.12.13/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
# ...
