# %%
import matplotlib.pyplot as plt
import cv2
import pathlib
import time
inputs_path = pathlib.Path("../inputs")
outputs_path = pathlib.Path("../outputs")
camera_path = outputs_path / "camera"
cam = cv2.VideoCapture(2)
cam.set(cv2.CAP_PROP_BUFFERSIZE, 1)
# Out:
# True

# %%
import modi_plus as modi
bundle = modi.MODIPlus()
bundle.modules
# Out:
# Initiating serial connection...
# Serial is open at "/dev/ttyACM0"
# Start initializing connected MODI+ modules
# Network(0xA5C) has been connected!
# MODI+ modules are initialized!

# %%
_, frame = cam.read()
cv2.imwrite(str(camera_path / f"{time.time_ns()}.jpg"), frame)
# Out:
# True
