# %%
import modi
# Out:
# Running PyMODI (v1.2.0)

# %%
modi.update_module_firmware((2838,))
# Out:
# Initiating serial connection...
# Serial is open at "/dev/ttyACM0 - MODI+ Network Modul"
# Make sure you have connected module(s) to update
# Resetting firmware updater's state
# Firmware update has been requested
